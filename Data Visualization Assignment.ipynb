# %%
import numpy as np
import pandas as pd
import seaborn as sd

# %%
titanic= sd.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sd.barplot(x='survived',y='age',data=titanic,palette='vlag')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sd.relplot(data=titanic,x='class',y='fare',)

# %%
sd.countplot(x='class',hue='who',data=titanic,palette='YlOrBr')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
x=sd.lmplot(x='survived',y='fare',data=titanic)

# %%
sd.regplot(x='pclass',y='age',data=titanic)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sd.boxplot(x='age',y='fare',data=titanic)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
sd.barplot(x='embark_town',y='fare',color='red',data=titanic)
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='fare'>

# %%
sd.countplot(x='who',hue='alive',data=titanic,color='Yellow')
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
sd.regplot(x='fare',y='age',data=titanic)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>
